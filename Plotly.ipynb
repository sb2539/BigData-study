# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Bar(y=[2,3,1]))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c3d3566d-2fb8-475a-a9c3-c0d5a3bfd7cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c3d3566d-2fb8-475a-a9c3-c0d5a3bfd7cb")) {
#                     Plotly.newPlot(
#                         'c3d3566d-2fb8-475a-a9c3-c0d5a3bfd7cb',
#                         [{"type": "bar", "y": [2, 3, 1]}],
# ...

# %% [markdown]
# #. Bar Chart

# %%
# bar chart

langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

data = [go.Bar(
    x = langs,
    y = students
)]

fig = go.Figure(data = data)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5375cbea-3b41-4eff-b53b-ca4f6581f0b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5375cbea-3b41-4eff-b53b-ca4f6581f0b8")) {
#                     Plotly.newPlot(
#                         '5375cbea-3b41-4eff-b53b-ca4f6581f0b8',
# ...

# %%
# Grouped bar chart 만들기

# 선언
branches = ['CSE', 'Mech', 'Eletronics']
fy = [23, 17, 35]
sy = [20, 23, 30]
ty = [30, 20, 15]
# 그룹화

trace1 = go.Bar(
    x = branches,
    y = fy,
    name = 'FY'
)
trace2 = go.Bar(
    x = branches,
    y = sy,
    name = 'SY'
)
trace3 = go.Bar(
    x = branches,
    y = ty,
    name = 'TY'
)
# 출력
data = [trace1, trace2, trace3]
layout = go.Layout(barmode = 'group', title='Departments')
fig = go.Figure(data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c792561a-3913-433e-b4c8-bb1d818afe27" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c792561a-3913-433e-b4c8-bb1d818afe27")) {
#                     Plotly.newPlot(
#                         'c792561a-3913-433e-b4c8-bb1d818afe27',
# ...

# %%
# stack 으로 막대 표시
data = [trace1, trace2, trace3]
layout = go.Layout(barmode = 'stack', title='Departments')
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="987ff176-487a-46a3-8e24-85e9765a9230" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("987ff176-487a-46a3-8e24-85e9765a9230")) {
#                     Plotly.newPlot(
#                         '987ff176-487a-46a3-8e24-85e9765a9230',
# ...

# %%
# Customized color

#  변수 선언
years = [1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
    2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]

rest = [219, 146, 112, 127, 124, 180, 236, 207, 236, 263, 350, 430,
    474, 526, 488, 537, 500, 439]

china = [16, 13, 10, 11, 28, 37, 43, 55, 56, 88, 105, 156, 270, 299,
    340, 403, 549, 499]

trace1 = go.Bar(
    x = years,
    y = rest,
    name = 'Rest of the World',
    marker = dict(
    color = 'rgb(49,130,189)',
    opacity = 0.7
    ))
trace2 = go.Bar(
    x = years,
    y = china,
    name = 'China',
    marker = dict(
    color = 'rgb(204,204,204)',
    opacity = 0.5
    ))    

data = [trace1, trace2]
layout = go.Layout(barmode = 'group', title='Export of Plastic Scrap')
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0feb1b0b-d40f-4ab5-ab53-70e2d54ac500" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0feb1b0b-d40f-4ab5-ab53-70e2d54ac500")) {
#                     Plotly.newPlot(
#                         '0feb1b0b-d40f-4ab5-ab53-70e2d54ac500',
# ...

# %%
# Label annotation

# 변수 선언
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
          'Oct', 'Nov', 'Dec']
primary_sales = [20, 14, 25, 16, 18, 22, 19, 15, 12, 16, 14, 17]
secondary_sales = [19, 14, 22, 14, 16, 19, 15, 14, 10, 12, 12, 16]

trace1 = go.Bar(
    x = months,
    y = primary_sales,
    name = 'Primary Product',
    marker = dict(
        color = 'rgb(49,130,189)',
        opacity = 0.7
    ),
    text = primary_sales,
    textposition = 'auto',
)
trace2 = go.Bar(
    x = months,
    y = secondary_sales,
    name = 'Secondary Product',
    marker = dict(
        color = 'rgb(204,204,204)',
        opacity = 0.5
    ),
    text = secondary_sales,
    textposition = 'auto',
)

data = [trace1, trace2]
layout = go.Layout(barmode = 'group', title='2020 Sales Report')
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4c96f1fa-b60a-4fc6-904e-db264bf79ece" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4c96f1fa-b60a-4fc6-904e-db264bf79ece")) {
#                     Plotly.newPlot(
#                         '4c96f1fa-b60a-4fc6-904e-db264bf79ece',
# ...

# %% [markdown]
# # Pie Chart

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
data = [go.Pie(
    labels = langs,
    values = students,
    pull = [0.1,0,0,0,0])]
    
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4ae5bdd5-5a7b-4c37-826a-c566a6e319f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ae5bdd5-5a7b-4c37-826a-c566a6e319f6")) {
#                     Plotly.newPlot(
#                         '4ae5bdd5-5a7b-4c37-826a-c566a6e319f6',
# ...

# %%
# subplot()
from plotly.subplots import make_subplots

# 변수선언
countries = ["US", "China", "European Union", "RussianFederation", "Brazil", "India", "Rest of World"]
ghg = [16, 15, 12, 6, 5, 4, 42]
co2 = [27, 11, 25, 8, 1, 3, 25]
# create subplot : use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
# Create subplots: use 'domain' type for Pie subplot 4개 만들기
#specs = [[{'type':'domain'}, {'type':'domain'}], [{'type':'domain'}, {'type':'domain'}]]
#fig = make_subplots(rows=2, cols=2, specs=specs)

# Creating traces
fig.add_trace(go.Pie(
    labels=countries,
    values=ghg,
    name="GHG Emissions"),
    row=1, col=1)

fig.add_trace(go.Pie(
    labels=countries,
    values=co2,
    name="CO2 Emissions"),
    row = 1, col = 2)
# Creating layout
fig.update_traces(hole=.4, hoverinfo="label+percent+name")

fig.update_layout(
    title_text="Global Emissions 1990-2011",
    annotations=[dict(text='GHG', x=0.18, y=0.5, font_size=20, showarrow=False),
                 dict(text='CO2', x=0.82, y=0.5, font_size=20, showarrow=False)])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="de998437-2bcb-4b9c-8c4d-81de563c22fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("de998437-2bcb-4b9c-8c4d-81de563c22fe")) {
#                     Plotly.newPlot(
#                         'de998437-2bcb-4b9c-8c4d-81de563c22fe',
# ...

# %% [markdown]
# # Scatter Plot

# %%
import numpy as np

# 난수 생성 
N = 100
x_vals = np.linspace(0, 1, N)
y1 = np.random.randn(N) + 5
y2 = np.random.randn(N)
y3 = np.random.randn(N) - 5

trace0 = go.Scatter(
    x = x_vals,
    y = y1,
    mode = 'markers',
    name = 'markers')


trace1 = go.Scatter(
    x = x_vals,
    y = y2,
    mode = 'lines+markers',
    name = 'line+markers')

trace2 = go.Scatter(
    x = x_vals,
    y = y3,
    mode = 'lines',
    name = 'line')

# 출력
data = [trace0, trace1, trace2]
fig = go.Figure(data = data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="23178a32-b756-449c-9fa1-4fefef0b5a65" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23178a32-b756-449c-9fa1-4fefef0b5a65")) {
#                     Plotly.newPlot(
#                         '23178a32-b756-449c-9fa1-4fefef0b5a65',
# ...

# %% [markdown]
# # Dot Plot

# %%
# 변수 선언
schools = ["Brown", "NYU", "Notre Dame", "Cornell", "Tufts", "Yale",
           "Dartmouth", "Chicago", "Columbia", "Duke", "Georgetown",
           "Princeton", "U.Penn", "Stanford", "MIT", "Harvard"]

# 데이터 준비
trace1 = go.Scatter(
    x=[72, 67, 73, 80, 76, 79, 84, 78, 86, 93, 94, 90, 92, 96, 94, 112],
    y=schools,
    marker=dict(color="crimson", size=12),
    mode="markers",
    name="Women",)

trace2 = go.Scatter(
    x=[92, 94, 100, 107, 112, 114, 114, 118, 119, 124, 131, 137, 141, 151, 152, 165],
    y=schools,
    marker=dict(color="gold", size=12),
    mode="markers",
    name="Men",)
# 출력
data = [trace1, trace2]
layout = go.Layout(title="Gender Earnings Disparity",
                   xaxis_title="Annual Salary (in thousands)",
                   yaxis_title="School")
fig = go.Figure(data=data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a35cdd45-fe21-4209-9412-a8edb971e3c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a35cdd45-fe21-4209-9412-a8edb971e3c0")) {
#                     Plotly.newPlot(
#                         'a35cdd45-fe21-4209-9412-a8edb971e3c0',
# ...

# %% [markdown]
# # Histogram

# %%
np.random.seed(1)
x = np.random.randn(500)
data = [go.Histogram(x = x)]
fig = go.Figure(data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="294650aa-6b11-4217-9712-3cd1bbbc7c5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("294650aa-6b11-4217-9712-3cd1bbbc7c5f")) {
#                     Plotly.newPlot(
#                         '294650aa-6b11-4217-9712-3cd1bbbc7c5f',
# ...

# %%
# ocerlayed histogram

x0 = np.random.randn(500)
x1 = np.random.randn(500) + 1
fig = go.Figure()
fig.add_trace(go.Histogram(x=x0))
fig.add_trace(go.Histogram(x=x1))
fig.update_layout(barmode='overlay')
fig.update_traces(opacity=0.75)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e5415124-1dd6-4c75-9731-aeff47c44c33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e5415124-1dd6-4c75-9731-aeff47c44c33")) {
#                     Plotly.newPlot(
#                         'e5415124-1dd6-4c75-9731-aeff47c44c33',
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# make Plotly histogram using pandas
import plotly.graph_objects as go
import pandas as pd

movies_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/IMDB-Movie-Data.csv",index_col="Title")
x_values = movies_df['Rating']
mydata = go.Histogram(x=x_values)

mylayout = go.Layout(title='Rating frequencies',
                     xaxis_title = 'Rating',
                     yaxis_title="Frequency")
fig = go.Figure(data = mydata, layout = mylayout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b5a43f5e-0b7c-41ab-9d84-7ea461da72f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5a43f5e-0b7c-41ab-9d84-7ea461da72f3")) {
#                     Plotly.newPlot(
#                         'b5a43f5e-0b7c-41ab-9d84-7ea461da72f3',
# ...

# %% [markdown]
# # 2d histogram

# %%
np.random.seed(1)
x = np.random.randn(500)
y = np.random.randn(500)+1
fig = go.Figure(go.Histogram2d(x=x,y=y))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="234dfba1-8e34-4789-9f28-bfa5ad3ff46b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("234dfba1-8e34-4789-9f28-bfa5ad3ff46b")) {
#                     Plotly.newPlot(
#                         '234dfba1-8e34-4789-9f28-bfa5ad3ff46b',
# ...

# %%
movies_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/IMDB-Movie-Data.csv",index_col="Title")
x = movies_df['Rating']
y = movies_df['Year']
fig = go.Figure(go.Histogram2d(x=x,y=y))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4cb78fd3-99fb-483c-bc50-d78c25d6437b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4cb78fd3-99fb-483c-bc50-d78c25d6437b")) {
#                     Plotly.newPlot(
#                         '4cb78fd3-99fb-483c-bc50-d78c25d6437b',
# ...

# %% [markdown]
# # boxplot

# %%
yaxis = [1140,1460,489,594,502,508,370,200]
data = go.Box(y = yaxis)
fig = go.Figure(data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="196241d5-6e48-4529-9a37-5eee86fc080c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("196241d5-6e48-4529-9a37-5eee86fc080c")) {
#                     Plotly.newPlot(
#                         '196241d5-6e48-4529-9a37-5eee86fc080c',
# ...

# %%
# using pandas for boxplot

movies_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/IMDB-Movie-Data.csv",index_col="Title")
y_values = movies_df['Rating']
mydata = go.Box(y = y_values)
mylayout = go.Layout(title='Boxplot for Ratings', yaxis_title="Rating")
fig = go.Figure(mydata, mylayout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="19aebc6a-135c-4596-a829-dfcb25d3ddd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("19aebc6a-135c-4596-a829-dfcb25d3ddd1")) {
#                     Plotly.newPlot(
#                         '19aebc6a-135c-4596-a829-dfcb25d3ddd1',
# ...

# %% [markdown]
# # violin plot

# %%
np.random.seed(10)
c1 = np.random.normal(100, 10, 200)
c2 = np.random.normal(80, 30, 200)
trace1 = go.Violin(y = c1, meanline_visible = True)
trace2 = go.Violin(y = c2, box_visible = True)
data = [trace1, trace2]
fig = go.Figure(data = data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cf174048-e825-44f1-beb8-c23041afa37d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cf174048-e825-44f1-beb8-c23041afa37d")) {
#                     Plotly.newPlot(
#                         'cf174048-e825-44f1-beb8-c23041afa37d',
# ...

# %% [markdown]
# # HOME WORK

# %%
# draw bar graph
df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")


data = [go.Bar(
    x = df['model'].unique()
    y = df['model'].value_counts(),   
)]
fig = go.Figure(data)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b2f02080-f168-4711-8bed-b56b15b0c47c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2f02080-f168-4711-8bed-b56b15b0c47c")) {
#                     Plotly.newPlot(
#                         'b2f02080-f168-4711-8bed-b56b15b0c47c',
# ...

# %%
# draw grouped bar graph

df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
# 선언
branches = df['model'].unique()
fy = [33, 77, 95]
sy = [12, 15, 60]
# 그룹화

trace1 = go.Bar(
    x = branches,
    y = fy,
    name = 'fy'
)
trace2 = go.Bar(
    x = branches,
    y = sy,
    name = 'sy'
)
# 출력
data = [trace1, trace2]
layout = go.Layout(barmode = 'group', title='Departments')
fig = go.Figure(data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5c8d54b5-e497-47db-abe4-f96d8a61de59" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5c8d54b5-e497-47db-abe4-f96d8a61de59")) {
#                     Plotly.newPlot(
#                         '5c8d54b5-e497-47db-abe4-f96d8a61de59',
# ...

# %%
# draw grouped bar graph and change color

df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
# 선언
branches = df['model'].unique()
fy = [33, 77, 95]
sy = [12, 15, 60]
# 그룹화

trace1 = go.Bar(
    x = branches,
    y = fy,
    name = 'fy',
    marker = dict(
    color = 'rgb(49,130,189)',
    opacity = 0.7
    )
)
trace2 = go.Bar(
    x = branches,
    y = sy,
    name = 'sy',
    marker = dict(
    color = 'rgb(49,60,189)',
    opacity = 0.7
    )
)
# 출력
data = [trace1, trace2]
layout = go.Layout(barmode = 'group', title='Departments')
fig = go.Figure(data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e141fa07-2b46-458a-9356-ced53fa6e4e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e141fa07-2b46-458a-9356-ced53fa6e4e5")) {
#                     Plotly.newPlot(
#                         'e141fa07-2b46-458a-9356-ced53fa6e4e5',
# ...

# %%
df['color'].unique()
# Out:
# array(['Yellow', 'Gray', 'Silver', 'White', 'Blue', 'Black', 'Green',
#        'Red', 'Gold'], dtype=object)

# %%
#pie chart
df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
# 선언
color = df['color'].unique()
color_num = df['color'].value_counts()
data = [go.Pie(
    labels = color,
    values = color_num,
    pull = [0.1,0,0,0,0])]
    
fig = go.Figure(data=data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0cbd1f9f-c0ae-48e3-87e4-54214e5966ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0cbd1f9f-c0ae-48e3-87e4-54214e5966ff")) {
#                     Plotly.newPlot(
#                         '0cbd1f9f-c0ae-48e3-87e4-54214e5966ff',
# ...

# %%
#scatter
df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
color = df['color'].unique()
color_num = df['color'].value_counts()
trace0 = go.Scatter(
    x = color,
    y = color_num,
    mode = 'markers',
    name = 'markers'
)
data = [trace0]
fig = go.Figure(data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f00c169b-07b6-4832-9feb-56bdf74c24e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f00c169b-07b6-4832-9feb-56bdf74c24e3")) {
#                     Plotly.newPlot(
#                         'f00c169b-07b6-4832-9feb-56bdf74c24e3',
# ...

# %%
# histogram
import plotly.graph_objects as go
import pandas as pd

usedcar_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
x_values = usedcar_df['mileage']
mydata = go.Histogram(x=x_values)

mylayout = go.Layout(title='model frequencies',
                     xaxis_title = 'mileage',
                     yaxis_title="frequencies")
fig = go.Figure(data = mydata, layout = mylayout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4f397a0f-0782-498a-a5aa-23071789a410" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4f397a0f-0782-498a-a5aa-23071789a410")) {
#                     Plotly.newPlot(
#                         '4f397a0f-0782-498a-a5aa-23071789a410',
# ...

# %%
# 2d histogram
usedcar_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
x = usedcar_df['year']
y = usedcar_df['color']
fig = go.Figure(go.Histogram2d(x=x,y=y))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8b7af82d-9bce-4817-a34e-08f89537990a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8b7af82d-9bce-4817-a34e-08f89537990a")) {
#                     Plotly.newPlot(
#                         '8b7af82d-9bce-4817-a34e-08f89537990a',
# ...

# %%
# using pandas for boxplot

usedcar_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
y_values = usedcar_df['mileage']
mydata = go.Box(y = y_values)
mylayout = go.Layout(title='Boxplot for Mileages', yaxis_title="Mileage")
fig = go.Figure(mydata, mylayout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4da09d79-776e-4fd8-a281-d670433ae682" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4da09d79-776e-4fd8-a281-d670433ae682")) {
#                     Plotly.newPlot(
#                         '4da09d79-776e-4fd8-a281-d670433ae682',
# ...

# %%
# violin
usedcar_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")
y_values = usedcar_df['mileage']
trace0 = go.Violin(y = y_values, meanline_visible = True)
data = [trace0]
fig = go.Figure(data)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8266d528-4fca-42c0-b2a1-c718d1fdb6e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8266d528-4fca-42c0-b2a1-c718d1fdb6e2")) {
#                     Plotly.newPlot(
#                         '8266d528-4fca-42c0-b2a1-c718d1fdb6e2',
# ...
