# %%
import pandas
print(pandas.__version__)
# Out:
# 1.1.5

# %%
# Series=> pandas.Series(data, index, dtype, copy)

# %%
import pandas as pd
import numpy as np

data = np.array(['a', 'b', 'c', 'd'])
series = pd.Series(data, index=[100, 101, 102, 103])

print(series)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
# dict 이용한 series

data = {100:'a', 101:'b', 102:'c', 103:'d'}
series = pd.Series(data)

print(series)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %%
#Task

data = {1:'A', 2:'B', 3:'C', 4:'D', 5:'E'}
series = pd.Series(data)

print(series)
# Out:
# 1    A
# 2    B
# 3    C
# 4    D
# 5    E
# dtype: object

# %% [markdown]
# #.Data frame

# %%
# Data frame = > pandas.DataFrame(data, index, columns, dtype, copy)

# %%
# List 이용한 data frame

data = [['Tim', 35],['Sonya', 30],['Sunny', 34]]
df = pd.DataFrame(data, columns=['Name', 'Age'], dtype=float)
print(df)
# Out:
#     Name   Age
# 0    Tim  35.0
# 1  Sonya  30.0
# 2  Sunny  34.0

# %%
# Dict of series 이용한 data frame 만드는 방법

data = {'one':pd.Series([1,2,3], index=['a','b','c']),
        'two':pd.Series([1,2,3,4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(data)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
# Task??

data = {'Artist':pd.Series(['Billie Holiday','Jimi Hendrix','Miles Davis', 'SIA']),
        'Genre':pd.Series(['Jazz', 'Rock', 'Jazz', 'Pop']),
        'Listeners':pd.Series([1300000, 2700000, 1500000, 2000000]),
        'Plays':pd.Series([27000000, 70000000, 48000000, 74000000])}
df = pd.DataFrame(data)
print(df)
# Out:
#            Artist Genre  Listeners     Plays
# 0  Billie Holiday  Jazz    1300000  27000000
# 1    Jimi Hendrix  Rock    2700000  70000000
# 2     Miles Davis  Jazz    1500000  48000000
# 3             SIA   Pop    2000000  74000000

# %% [markdown]
# # Data Processing in Pandas

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
pd.set_option('display.max_columns',11)

# %%
movies_df = pd.read_csv("/gdrive/MyDrive/BigDataStudy/IMDB-Movie-Data.csv",
                        index_col = "Title")

print(movies_df)
# Out:
#                          Rank  ... Metascore
# Title                          ...
# Guardians of the Galaxy     1  ...      76.0
# Prometheus                  2  ...      65.0
# Split                       3  ...      62.0
# Sing                        4  ...      59.0
# Suicide Squad               5  ...      40.0
# ...                       ...  ...       ...
# Secret in Their Eyes      996  ...      45.0
# Hostel: Part II           997  ...      46.0
# Step Up 2: The Streets    998  ...      50.0
# Search Party              999  ...      22.0
# Nine Lives               1000  ...      11.0
#
# [1000 rows x 11 columns]

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.tail(10)
# Out:
#                                 Rank                     Genre  \
# Title
# Underworld: Rise of the Lycans   991  Action,Adventure,Fantasy
# Taare Zameen Par                 992        Drama,Family,Music
# Take Me Home Tonight             993      Comedy,Drama,Romance
# Resident Evil: Afterlife         994   Action,Adventure,Horror
# Project X                        995                    Comedy
# Secret in Their Eyes             996       Crime,Drama,Mystery
# Hostel: Part II                  997                    Horror
# Step Up 2: The Streets           998       Drama,Music,Romance
# Search Party                     999          Adventure,Comedy
# Nine Lives                      1000     Comedy,Family,Fantasy
#
#                                                                       Description  \
# Title
# Underworld: Rise of the Lycans  An origins story centered on the centuries-old...
# Taare Zameen Par                An eight-year-old boy is thought to be a lazy ...
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 133.8+ KB

# %%
movies_df.shape
# Out:
# (1000, 11)

# %%
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
movies_df['Genre'].describe()
# Out:
# count                        1000
# unique                        207
# top       Action,Adventure,Sci-Fi
# freq                           50
# Name: Genre, dtype: object

# %%
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
movies_df.rename(columns={
    'Runtime (Minutes)': 'Runtime',
}, inplace = True)
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue (Millions)', 'Metascore'],
#       dtype='object')

# %%
# Task
movies_df.rename(columns={
    'Revenue (Millions)': 'Revenue_millions',
}, inplace = True)
movies_df.columns
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime',
#        'Rating', 'Votes', 'Revenue_millions', 'Metascore'],
#       dtype='object')

# %%
# column 선택해서 보기
subset = movies_df[['Genre', 'Rating']]
subset.head()
# Out:
#                                             Genre  Rating
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi     8.1
# Prometheus               Adventure,Mystery,Sci-Fi     7.0
# Split                             Horror,Thriller     7.3
# Sing                      Animation,Comedy,Family     7.2
# Suicide Squad            Action,Adventure,Fantasy     6.2

# %%
movies_df[movies_df['Year'] == 2012].head(5)
# Out:
#                             Rank                     Genre  \
# Title
# Prometheus                     2  Adventure,Mystery,Sci-Fi
# The Avengers                  77             Action,Sci-Fi
# The Dark Knight Rises        125           Action,Thriller
# The Place Beyond the Pines   136      Crime,Drama,Thriller
# Django Unchained             145             Drama,Western
#
#                                                                   Description  \
# Title
# Prometheus                  Following clues to the origin of mankind, a te...
# The Avengers                Earth's mightiest heroes must come together an...
# The Dark Knight Rises       Eight years after the Joker's reign of anarchy...
# The Place Beyond the Pines  A motorcycle stunt rider turns to robbing bank...
# Django Unchained            With the help of a German bounty hunter , a fr...
#
#                                      Director  \
# Title
# Prometheus                       Ridley Scott
# ...

# %%
movies_df[movies_df['Rating'] >= 8.6].head(5)
# Out:
#                  Rank                    Genre  \
# Title
# Interstellar       37   Adventure,Drama,Sci-Fi
# The Dark Knight    55       Action,Crime,Drama
# Inception          81  Action,Adventure,Sci-Fi
# Kimi no na wa      97  Animation,Drama,Fantasy
# Dangal            118   Action,Biography,Drama
#
#                                                        Description  \
# Title
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# Inception        A thief, who steals corporate secrets through ...
# Kimi no na wa    Two strangers find themselves linked in a biza...
# Dangal           Former wrestler Mahavir Singh Phogat and his t...
#
#                           Director  \
# Title
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# Inception        Christopher Nolan
# Kimi no na wa       Makoto Shinkai
# Dangal               Nitesh Tiwari
#
# ...

# %%
movies_df[(movies_df['Director'] == 'Christopher Nolan') |
          (movies_df['Director'] == 'Ridley Scott')].head(5)
# Out:
#                  Rank                     Genre  \
# Title
# Prometheus          2  Adventure,Mystery,Sci-Fi
# Interstellar       37    Adventure,Drama,Sci-Fi
# The Dark Knight    55        Action,Crime,Drama
# The Prestige       65      Drama,Mystery,Sci-Fi
# Inception          81   Action,Adventure,Sci-Fi
#
#                                                        Description  \
# Title
# Prometheus       Following clues to the origin of mankind, a te...
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# The Prestige     Two stage magicians engage in competitive one-...
# Inception        A thief, who steals corporate secrets through ...
#
#                           Director  \
# Title
# Prometheus            Ridley Scott
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# The Prestige     Christopher Nolan
# Inception        Christopher Nolan
#
# ...

# %%
movies_df.sort_values(by='Year', ascending=False).head(5)
# Out:
#                                     Rank                    Genre  \
# Title
# Nine Lives                          1000    Comedy,Family,Fantasy
# Free Fire                            162      Action,Comedy,Crime
# Tall Men                             648  Fantasy,Horror,Thriller
# The Huntsman: Winter's War           235   Action,Adventure,Drama
# Popstar: Never Stop Never Stopping   654             Comedy,Music
#
#                                                                           Description  \
# Title
# Nine Lives                          A stuffy businessman finds himself trapped ins...
# Free Fire                           Set in Boston in 1978, a meeting in a deserted...
# Tall Men                            A challenged man is stalked by tall phantoms i...
# The Huntsman: Winter's War          Eric and fellow warrior Sara, raised as member...
# Popstar: Never Stop Never Stopping  When it becomes clear that his solo album is a...
#
# ...

# %%
# null 값 찾기
movies_df.isnull().tail(5)
# Out:
#                          Rank  Genre  Description  Director  Actors   Year  \
# Title
# Secret in Their Eyes    False  False        False     False   False  False
# Hostel: Part II         False  False        False     False   False  False
# Step Up 2: The Streets  False  False        False     False   False  False
# Search Party            False  False        False     False   False  False
# Nine Lives              False  False        False     False   False  False
#
#                         Runtime  Rating  Votes  Revenue_millions  Metascore
# Title
# Secret in Their Eyes      False   False  False              True      False
# Hostel: Part II           False   False  False             False      False
# Step Up 2: The Streets    False   False  False             False      False
# Search Party              False   False  False              True      False
# Nine Lives                False   False  False             False      False

# %%
movies_df.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime               0
# Rating                0
# Votes                 0
# Revenue_millions    128
# Metascore            64
# dtype: int64

# %%
movies_df.dropna(inplace=True)
movies_df.isnull().sum()

# dropna(axis = 1 ) = > null 값 가진 열 삭제, axis = 0 이면 null 값 가긴 행 삭제
# Out:
# Rank                0
# Genre               0
# Description         0
# Director            0
# Actors              0
# Year                0
# Runtime             0
# Rating              0
# Votes               0
# Revenue_millions    0
# Metascore           0
# dtype: int64

# %%
# movies_df['Revenue_millions'].fillna(movies_df['Revenue_millions'].mean(), inplace = True)  # null 값에 해당 열의 평균값 대입 -> 안전한 방법

# %% [markdown]
# # Task

# %%
# 1 show summary using head(), tail(), info() and describe()

# %%
usedcars = pd.read_csv("/gdrive/MyDrive/BigDataStudy/usedcars.csv")

print(usedcars)
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992   7413.0  Yellow         AUTO
# 1    2011   SEL  20995  10926.0    Gray         AUTO
# 2    2011   SEL  19995   7351.0  Silver         AUTO
# 3    2011   SEL  17809  11613.0    Gray         AUTO
# 4    2012    SE  17500   8367.0   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200      NaN  Silver         AUTO
# 146  2002    SE   5995      NaN     Red         AUTO
# 147  2000    SE   5980      NaN     Red         AUTO
# 148  2001    SE   4899      NaN  Yellow         AUTO
# 149  2000    SE   3800      NaN     Red         AUTO
#
# [150 rows x 6 columns]

# %%
usedcars.head(10)
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992   7413.0  Yellow         AUTO
# 1  2011   SEL  20995  10926.0    Gray         AUTO
# 2  2011   SEL  19995   7351.0  Silver         AUTO
# 3  2011   SEL  17809  11613.0    Gray         AUTO
# 4  2012    SE  17500   8367.0   White         AUTO
# 5  2010   SEL  17495  25125.0  Silver         AUTO
# 6  2011   SEL  17000  27393.0    Blue         AUTO
# 7  2010   SEL  16995  21026.0  Silver         AUTO
# 8  2011   SES  16995  32655.0  Silver         AUTO
# 9  2010   SES  16995  36116.0  Silver         AUTO

# %%
usedcars.tail(5)
# Out:
#      year model  price  mileage   color transmission
# 145  2006   SES   6200      NaN  Silver         AUTO
# 146  2002    SE   5995      NaN     Red         AUTO
# 147  2000    SE   5980      NaN     Red         AUTO
# 148  2001    SE   4899      NaN  Yellow         AUTO
# 149  2000    SE   3800      NaN     Red         AUTO

# %%
usedcars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          150 non-null    int64
#  1   model         150 non-null    object
#  2   price         150 non-null    int64
#  3   mileage       129 non-null    float64
#  4   color         150 non-null    object
#  5   transmission  150 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 7.2+ KB

# %%
usedcars.describe()
# Out:
#               year         price        mileage
# count   150.000000    150.000000     129.000000
# mean   2008.993333  14242.353333   37531.666667
# std       3.288166   9773.811205   20122.776366
# min    2000.000000   3800.000000    4867.000000
# 25%    2008.000000  10995.000000   24920.000000
# 50%    2009.000000  13631.000000   35574.000000
# 75%    2010.000000  14989.750000   44518.000000
# max    2030.000000  90000.000000  127327.000000

# %%
# 2 change name of columns

# %%
usedcars.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
usedcars.rename(columns={
    'price': 'prices',
}, inplace = True)
usedcars.columns
# Out:
# Index(['year', 'model', 'prices', 'mileage', 'color', 'transmission'], dtype='object')

# %%
# 3 perform at least three data manipulation

# %%
usedcars[usedcars['year'] == 2002].head(5)
# Out:
#      year model  prices  mileage color transmission
# 146  2002    SE    5995      NaN   Red         AUTO

# %%
usedcars[(usedcars['color'] == 'Red') |
          (usedcars['color'] == 'Black')].head(5)
# Out:
#     year model  prices  mileage  color transmission
# 10  2010   SES   16995  40539.0  Black         AUTO
# 13  2010   SES   16950  32058.0    Red         AUTO
# 23  2010   SEL   15889  24920.0  Black         AUTO
# 26  2010    SE   15499   7784.0  Black         AUTO
# 27  2010    SE   15499  35636.0  Black         AUTO

# %%
usedcars[usedcars['prices'] >= 15500].head(5)
# Out:
#    year model  prices  mileage   color transmission
# 0  2011   SEL   21992   7413.0  Yellow         AUTO
# 1  2011   SEL   20995  10926.0    Gray         AUTO
# 2  2011   SEL   19995   7351.0  Silver         AUTO
# 3  2011   SEL   17809  11613.0    Gray         AUTO
# 4  2012    SE   17500   8367.0   White         AUTO

# %%
# 4 check if we heave null values

# %%
usedcars.isnull().sum()
# Out:
# year             0
# model            0
# prices           0
# mileage         21
# color            0
# transmission     0
# dtype: int64

# %%
# 5 replace null values with mean() values

# %%
usedcars['mileage'].fillna(usedcars['mileage'].mean(),
                           inplace = True)
usedcars.isnull().sum()
# Out:
# year            0
# model           0
# prices          0
# mileage         0
# color           0
# transmission    0
# dtype: int64
